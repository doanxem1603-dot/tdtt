# %% [markdown]
# <a href="https://colab.research.google.com/github/doanxem1603-dot/tdtt/blob/tdtt/btvn3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a, b = map(int, input().split())
print(a * b, (a + b) * 2)
# Out:
# 4 5
# 20 18

# %%
n = int(input())
print(n ** 2 * 3.14, n * 2 * 3.14)
# Out:
# 3
# 28.26 18.84

# %%
a, b, c = map(int, input().split())
if a + b > c or b + c > a or a + c > b:
  print("tam giac")
else:
  print(" k la tam giac")
# Out:
# 3 4 5
# tam giac

# %%
a, b = map(int, input().split())
if a = 0

# %%
a, b, c, d = map(int,input().split())
print(max(a,b,c,d))
# Out:
# 1 2 3 4
# 4

# %%
a, b, c, d = map(int,input().split())
print(min(a,b,c,d))
# Out:
# 1 2  3 4
# 1

# %%
ss = int(input())
gio = ss // 3600
phut = (ss - gio * 3600 ) // 60
s = ss - gio * 3600 - phut * 60
print(f"{gio}h {phut} phut {s} s")
# Out:
# 4000
# 1h 6 phut 40 s
