# %% [markdown]
# <a href="https://colab.research.google.com/github/doanxem1603-dot/tdtt/blob/tdtt/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list = [1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
colours = ["green","blue","red","ornage"]
print(colours[2])
# Out:
# red

# %%
so = [1,2,3,4]
so.insert(1,5)
print(so)
# Out:
# [1, 5, 2, 3, 4]

# %%
list = [1,2,3,4,5]
list.remove(2)
print(list)
# Out:
# [1, 3, 4, 5]

# %%
list = [1,5,6,7,4,3,2]
list.sort()
print(list)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
list = [1,2,3,4,5]
list.reverse()
print(list)
# Out:
# [5, 4, 3, 2, 1]

# %%
list = [1,2,3,4,5,2,3,4,2,1,2]
while 2 in list:
  list.remove(2)
print(list)
# Out:
# [1, 3, 4, 5, 3, 4, 1]

# %%
list =[1,2,3,4]
b = sorted(list)
print(list)
print(test)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
list =[1,2,3,4]
print(list.index(2))
# Out:
# 1

# %%
list =[1,2,3,4]
print(4 in list)
# Out:
# True

# %%
so = [1,2,3,4]
so.append(5)
print(so)
# Out:
# [1, 2, 3, 4, 5]

# %%
s1 = {1,2,3,4,5}
s2 = {3,4,5,6,7}
s1&s2 #giao của 2 list
s1 - s2 #có 1 mà k có 2
s1^s2 # phép so k có phần chung
s1 | s2 #có cả hai
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a = {'name':'Toanh','age':19}
print(a)
# Out:
# {'name': 'Toanh', 'age': 19}

# %%
a = {'name':'Toanh','age':19}
a['name'] = 'Trang'
print(a)
# Out:
# {'name': 'Trang', 'age': 19}

# %%
a = {'name':'Toanh','age':19, 'sex':{0: 'male',1: 'female'}}
a['sex'][0]
# Out:
# 'male'

# %%
a = {'name':'Toanh','age':19}
