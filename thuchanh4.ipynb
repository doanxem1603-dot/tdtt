# %% [markdown]
# <a href="https://colab.research.google.com/github/doanxem1603-dot/tdtt/blob/tdtt/thuchanh4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input())
if n < 1000:
    print(f"invalid")
else:
    while n>0:
        a = n % 10
        n = n // 10
        print(a, end='')
# Out:
# 1234
# 4321

# %%
n = int(input())
giaithua = 1
for i in range(1,n+1):
  giaithua *= i
print(giaithua)
# Out:
# 4
# 24

# %%
n = int(input())
tongso = 0
while n > 0:
   n = n //10
   tongso +=1
print(tongso)
# Out:
# 1234
# 4

# %%
n = int(input())
tongsochan = 0
while n > 0:
  a = n % 10
  if a % 2 ==0:
    tongsochan += a
  n = n //10

print(tongsochan)
# Out:
# 432432
# 12

# %%
n = int(input())
for i in range(1,n+1):
  n % i == 0

# %%
n = int(input())
a = 0
for i in range(1,n+1):
  if i * i < n:
    a = i
    print(a ** 2, end=' ')
# Out:
# 20
# 1 4 9 16

# %%
a, b = map(int, input().split())
tong = 0
if 1 < a <= b:
  for i in range(a, b + 1):
    prime = True
    for j in range(2,int(i ** 0.5) + 1):
      if i % j == 0:
        prime = False
        break
    if prime == True:
        tong +=i

print(tong)
# Out:
# 10 20
# 60

# %%
n = int(input())
a = 0
for i in range(2, n +1):
  prime = True
  for j in range(2, int(i ** 0.5) + 1):
    if i % j ==0:
      prime = False
  if prime == True:
    if n % i == 0:
      a = i
print(a)
# Out:
# 26
# 13

# %%
n = int(input())
tong = 0
if n > 10 ** 6:
  print("invalid")
else:
  for i in range(1, n+1):
    if n % i ==0 and i % 2 ==0:
      tong +=1
print(tong)
# Out:
# 20
# 4

# %%
n = int(input())
print(f"{10 * (1.07 ** n):.2f}")
# Out:
# 10
# 19.67

# %%
m, n = map(int,input().split())
for i in range(min(m,n),1,-1):
  if m % i ==0 and n % i ==0:
    break
print(i)
# Out:
# 24 36
# 12
