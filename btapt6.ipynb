# %% [markdown]
# <a href="https://colab.research.google.com/github/doanxem1603-dot/tdtt/blob/tdtt/btapt6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = list(map(int,input().split()))
b = []
for x in a:
  if x not in b:
    b.append(x)
print(b)
# Out:
# 1 2 2 3 4
# [1, 2, 3, 4]

# %%
a = list(map(int,input().split()))
b = []
tong= 0
for x in a:
  tong +=x
  b.append(tong)

print(b)
# Out:
# 1 2 3 4
# [1, 3, 6, 10]

# %%
a = tuple(map(int,input().split()))
k = int(input())
k = k % len(a)
b = a[k:] + a[:k]
print(b)
# Out:
# 1 2 3 4 5
# 3
# (4, 5, 1, 2, 3)

# %%
a =
