# %% [markdown]
# <a href="https://colab.research.google.com/github/doanxem1603-dot/tdtt/blob/tdtt/thuchanhtuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")
# Out:
# hello world!

# %%
ten = input()
print("Helllo " + ten)
# Out:
# Toanh
# Helllo Toanh

# %%
a, b = map(int, input().split())
print(a + b, a - b, a * b, a // b)
# Out:
# 2 1
# 3 1 2 2

# %%
a1, b1, c1, a2, b2, a3 = map(int, input().split())
tong = (a1 + b1 + c1) + (a2 + b2) * 2 + a3 * 3
print(tong)
# Out:
# 1 1 1 1 1 1
# 10

# %%
a, b = map(int, input().split())
print(a ** b)
# Out:
# 2 3
# 8

# %%
thuong = input()
cochu = ord(thuong)
cochuhoa = cochu - 32
hoa = chr(cochuhoa)
print(hoa)
# Out:
# t
# T

# %%
a = ((13 ** 2) * 3) + 5
b = 13 ** 2 * 3 + 5
print(a, b)
# Out:
# 512 512

# %%
a, b, c = map(str, input().split())
a, b, c = c, b, a
print("HI " + a, b, c)
# Out:
# T H J
# HI J H T

# %%
gio, phut = map(int, input().split())
print(gio * 3600 + phut * 60)
# Out:
# 3 6
# 11160

# %%
a , b = map(int, input().split())
c = (a * b) % 10
print(c)
# Out:
# 3 4
# 2

# %%
a, b = map(int,input().split())
a, b = b, a
print(a, b)
# Out:
# 1 2
# 2 1
