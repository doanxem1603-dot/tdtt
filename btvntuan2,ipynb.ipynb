# %% [markdown]
# <a href="https://colab.research.google.com/github/doanxem1603-dot/tdtt/blob/tdtt/btvntuan2%2Cipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input())
print(n * 2)
# Out:
# 2
# 4

# %%
a, b = map(int, input().split())
print((a * b) - ((a * 0.5) ** 2 ) * 3.14)
# Out:
# 2 3
# 2.86

# %%
a, b, c = map(int, input().split())
p = (a + b + c) * 0.5
if a + b > c or a + c > b or b + c > a:
  S = (p * (p - a) * (p - b) * (p - c)) ** 0.5
  print(f"{S:.1f}")
else:
  print("k phai 3 canh tam giac")
# Out:
# 4 7 10
# 10.9

# %%
so_dien = int(input())
if so_dien <= 50:
    tien_dien = so_dien * 1984

elif so_dien <= 100:
    tien_dien = (50 * 1984) + (so_dien - 50) * 2050

elif so_dien <= 200:
    tien_dien = (50 * 1984) + (50 * 2050) + (so_dien - 100) * 2380

elif so_dien <= 300:
    tien_dien = (50 * 1984) + (50 * 2050) + (100 * 2380) + (so_dien - 200) * 2998

elif so_dien <= 400:
    tien_dien = (50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + (so_dien - 300) * 3350

else:
    tien_dien = (50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + (100 * 3350) + (so_dien - 400) * 3460

tongtien = int(tien_dien) * 1.08
print(f"{tongtien:.1f}")
# Out:
# 1070
# 3664116.0

# %%
n = int(input())
if n % 2 == 0:
  print("sochan")
else:
  print("sole")
# Out:
# 11
# sole

# %%
n = int(input())
if n % 5 ==0:
  print("true")
else:
  print("false")
# Out:
# 1025
# true

# %%
n = int(input())
if n % 5 ==0 and n % 3 ==0:
  print("true")
else:
  print("false")
# Out:
# 1035
# true

# %%
n = int(input())
if n > 18:
  print("đủ tuổi")
else:
  print(" k đc bầu cử")
# Out:
# 125
# đủ tuổi
